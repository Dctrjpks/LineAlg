# %% [raw]
# 1. Исследовать на линейную зависимость:
# 𝑓1(𝑥)=𝑒𝑥,𝑓2(𝑥)=1,𝑓3(𝑥)=𝑥+1,𝑓4(𝑥)=𝑥−𝑒𝑥.

# %% [raw]
# f3(x) = f3(x) - f2(x) - f1(x)

# %% [raw]
# Ответ: f4(x) линейно зависима от f1, f2, f3.

# %% [raw]
# 2. Исследовать на линейную зависимость:
# 𝑓1(𝑥)=2,𝑓2(𝑥)=𝑥,𝑓3(𝑥)=𝑥2,𝑓4(𝑥)=(𝑥+1)2.

# %% [raw]
# f4(x) = x**2 + 2*x + 1 = f3(x) + 2 * f2(x) +  1/2 * f1(x)

# %% [raw]
# Ответ: f4(x) линейно зависима от f1, f2, f3.

# %% [raw]
# 3. Найти координаты вектора 𝑥=(2,3,5)∈ℝ3 в базисе 𝑏1=(0,0,10), 𝑏2=(2,0,0), 𝑏3=(0,1,0)

# %% [raw]
# x(b) = 0.5*b1 + b2 + 3*b3
# x(0.5, 1, 3)

# %% [raw]
# 4. Найти координаты вектора 3𝑥2−2𝑥+2∈ℝ3[𝑥]:
# а) в базисе 1, 𝑥, 𝑥2

# %%
    (2, -2, 3)

# %% [raw]
# б) в базисе 𝑥2, 𝑥−1, 1.

# %%
    (3, -2, 0)

# %% [raw]
# 5.Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, являющиеся линейными комбинациями данных векторов {u_{1}, u_{2}, ..., u_{n}}.

# %% [raw]
# 1) 𝑢+𝑣∈𝐿;
#
# 2) 𝛼⋅𝑢∈𝐿.

# %% [raw]
# a) нет
# б) да

# %% [raw]
# 1. Найти скалярное произведение векторов 𝑥,𝑦∈ℝ:
# а) 𝑥=(0,−3,6), 𝑦=(−4,7,9);
# б) 𝑥=(7,−4,0,1), 𝑦=(−3,1,11,2).

# %% [raw]
# х * y = 0 - 21 + 54 = 33
# х * y = - 21 - 4 + 0 + 2 = - 23

# %% [raw]
# 2. Найти нормы векторов (4,2,4)
# и (12,3,4)
#
# и угол между ними.

# %% [raw]
# l(11) = 4 + 2 + 4 = 10
# l(12) = 12 + 3 + 4 = 19
#
# l(21) = SQRT(16 + 4 + 16) = SQRT(36) = 6
# l(22) = SQRT(144 + 9 + 16) = SQRT(169) = 13
#
# L = arccos ((v1*v2)/(l(21)*l(22))
# v1 * v2 = 48 + 6 + 16 = 70
# L = arccos (70/78) = 28.18 deg

# %% [raw]
# 3. Будет ли линейное пространство евклидовым, если за скалярное произведение принять:
# а) произведение длин векторов;
# б) утроенное обычное скалярное произведение векторов?

# %% [raw]
# 1) (𝑥,𝑦)=(𝑦,𝑥);
# 2) (𝜆𝑥,𝑦)=𝜆(𝑥,𝑦);
# 3) (𝑥1+𝑥2,𝑦)=(𝑥1,𝑦)+(𝑥2,𝑦);
# 4) (𝑥,𝑥)≥0, причем (𝑥,𝑥)=0⇔𝑥=0.
#
# а)  х * у = len(x) * len(y)
#     1 - да
#     2 - да
#     3 - нет
# б) x * y = 3(x * y)
#     1 - да
#     2 - да
#     3 - да
#     4 - да

# %% [raw]
# 4. Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве ℝ3:
# а) (1,0,0),(0,0,1);
# б) (1/2⎯⎯√,−1/2⎯⎯√,0),(1/2⎯⎯√,1/2⎯⎯√,0),(0,0,1);
# в) (1/2,−1/2,0),(0,1/2,1/2),(0,0,1);
# г) (1,0,0),(0,1,0),(0,0,1)?

# %% [raw]
# В конечномерном евклидовом пространстве базис {𝑒1,𝑒2,...,𝑒𝑛}называется ортонормированным, если
# (𝑒𝑖,𝑒𝑗)=0
# ∀ 𝑖≠𝑗 и (𝑒𝑖,𝑒𝑖)=1 ∀ 𝑖∈[1,𝑛].
#
# а) да
# б) да
# в) не ортогональны и не единичные
# г) да
